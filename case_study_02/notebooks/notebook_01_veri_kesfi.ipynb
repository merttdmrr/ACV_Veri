# %% [markdown]
# # Veri Keşfi ve Tanımlayıcı İstatistik

# %%
# Gerekli kütüphaneleri import et
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Excel dosyasını yükle
file_path = '../data/elektrik_veri_hashed.xlsx'
xls = pd.ExcelFile(file_path)

# Sayfa isimlerini görüntüle
print("Sayfa isimleri:", xls.sheet_names)

# Her sayfayı ayrı DataFrame'e yükle
df_tahsilat = pd.read_excel(xls, sheet_name='Tahsilat')
df_tahsilat_1 = pd.read_excel(xls, sheet_name='Tahsilat 1')
df_tahakkuk = pd.read_excel(xls, sheet_name='Tahakkuk')      # Hamamözü
df_tahakkuk_1 = pd.read_excel(xls, sheet_name='Tahakkuk 1')  # Gümüşhacıköy
df_tahakkuk_2 = pd.read_excel(xls, sheet_name='Tahakkuk 2')  # Göynücek

# DataFrame boyutlarını kontrol et
print(f"Tahsilat: {df_tahsilat.shape}")
print(f"Tahsilat 1: {df_tahsilat_1.shape}")
print(f"Tahakkuk (Hamamözü): {df_tahakkuk.shape}")
print(f"Tahakkuk 1 (Gümüşhacıköy): {df_tahakkuk_1.shape}")
print(f"Tahakkuk 2 (Göynücek): {df_tahakkuk_2.shape}")
# Out:
# Sayfa isimleri: ['Tahsilat', 'Tahsilat 1', 'Tahakkuk', 'Tahakkuk 1', 'Tahakkuk 2']
# Tahsilat: (636993, 9)
# Tahsilat 1: (917632, 22)
# Tahakkuk (Hamamözü): (124818, 10)
# Tahakkuk 1 (Gümüşhacıköy): (765657, 10)
# Tahakkuk 2 (Göynücek): (295223, 10)

# %%
dfs = {
    "Tahsilat": df_tahsilat,
    "Tahsilat (Zaman)": df_tahsilat_1,
    "Hamamözü (Tahakkuk)": df_tahakkuk,
    "Gümüşhacıköy (Tahakkuk 1)": df_tahakkuk_1,
    "Göynücek (Tahakkuk 2)": df_tahakkuk_2
}

# %%
for name, df in dfs.items():
    print(f"\n### {name} İncelemesi ###")
    print("-" * 30)
    print(df.info())
    print("-" * 30)
    print("\nİstatistiksel Özet:")
    print(df.describe().T)
    print("-" * 30)
    print("\nVeri seti:")
    print("-" * 30)
    print(df.head())
    print("-" * 30)
# Out:
# ### Tahsilat İncelemesi ###
# ------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636993 entries, 0 to 636992
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Şube                   636993 non-null  object
#  1   Kasa                   636993 non-null  object
#  2   İlçe                   636993 non-null  object
#  3   Söz.hsp.(bağımsız)     636993 non-null  int64
#  4   Tahsilat Tarihi        636993 non-null  datetime64[ns]
#  5   Nakit Tahsilat         523 non-null     float64
#  6   Mahsuben Tahsilat      7542 non-null    float64
#  7   Kredi Kartı Tahsilatı  0 non-null       float64
#  8   Banka Tahsilatı        628933 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(3)
# memory usage: 43.7+ MB
# None
# ------------------------------
#
# İstatistiksel Özet:
#                           count                           mean  \
# Söz.hsp.(bağımsız)     636993.0               5019884374.87975
# Tahsilat Tarihi          636993  2024-03-05 09:26:07.644856320
# Nakit Tahsilat            523.0                     694.966635
# Mahsuben Tahsilat        7542.0                    6180.182282
# Kredi Kartı Tahsilatı       0.0                            NaN
# Banka Tahsilatı        628933.0                     372.629109
#
#                                        min                  25%  \
# Söz.hsp.(bağımsız)                175832.0         2532887116.0
# Tahsilat Tarihi        2023-01-01 00:00:00  2023-07-28 00:00:00
# Nakit Tahsilat                        7.45               425.33
# Mahsuben Tahsilat                -34508.95              44.4775
# Kredi Kartı Tahsilatı                  NaN                  NaN
# Banka Tahsilatı                       0.01                120.0
#
#                                        50%                  75%  \
# Söz.hsp.(bağımsız)            5008502097.0         7525722213.0
# Tahsilat Tarihi        2024-02-26 00:00:00  2024-09-30 00:00:00
# Nakit Tahsilat                      524.67               688.83
# Mahsuben Tahsilat                   290.41              2729.11
# Kredi Kartı Tahsilatı                  NaN                  NaN
# Banka Tahsilatı                      208.0                322.0
#
#                                        max                std
# Söz.hsp.(bağımsız)            9999599851.0  2884434992.844679
# Tahsilat Tarihi        2025-05-31 00:00:00                NaN
# Nakit Tahsilat                    11373.74         758.319428
# Mahsuben Tahsilat                399526.78       23828.022593
# Kredi Kartı Tahsilatı                  NaN                NaN
# Banka Tahsilatı                   606473.8        3265.430202
# ------------------------------
#
# Veri seti:
# ------------------------------
#              Şube            Kasa    İlçe  Söz.hsp.(bağımsız) Tahsilat Tarihi  \
# 0  Tayin edilmedi  Tayin edilmedi  TAŞOVA          4989745446      2023-11-06
# 1  Tayin edilmedi  Tayin edilmedi  TAŞOVA          4989745446      2024-06-26
# 2  Tayin edilmedi  Tayin edilmedi  TAŞOVA          4989745446      2024-07-10
# 3             PTT          PTT/PV  TAŞOVA          4254955886      2023-01-19
# 4             PTT          PTT/PV  TAŞOVA          4254955886      2023-02-17
#
#    Nakit Tahsilat  Mahsuben Tahsilat  Kredi Kartı Tahsilatı  Banka Tahsilatı
# 0             NaN            8648.95                    NaN              NaN
# 1             NaN             762.40                    NaN              NaN
# 2             NaN             311.60                    NaN              NaN
# 3             NaN                NaN                    NaN            130.5
# 4             NaN                NaN                    NaN            117.0
# ------------------------------
#
# ### Tahsilat (Zaman) İncelemesi ###
# ------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 917632 entries, 0 to 917631
# Data columns (total 22 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Mali yıl/dönem                        917632 non-null  object
#  1   İl                                    917632 non-null  object
#  2   İlçe                                  917632 non-null  object
#  3   Söz.hsp.(bağımsız)                    917632 non-null  int64
#  4   Hesap Sınıfı                          917632 non-null  object
#  5   Tahakkuk Tutar                        917632 non-null  float64
#  6   Son Ödeme Tarihinden Önceki Tahsilat  623908 non-null  float64
#  7   Son Ödeme Tarihindeki Tahsilat        328193 non-null  float64
#  8   Son Ödeme (1)                         20902 non-null   float64
#  9   Son Ödeme (2)                         21664 non-null   float64
#  10  Son Ödeme (3)                         18893 non-null   float64
#  11  Son Ödeme (4)                         16995 non-null   float64
#  12  Son Ödeme (5)                         7323 non-null    float64
#  13  Son Ödeme (6-10)                      45708 non-null   float64
#  14  Son Ödeme (10-20)                     48281 non-null   float64
#  15  Son Ödeme (20-30)                     29005 non-null   float64
#  16  Son Ödeme (30-60)                     23030 non-null   float64
#  17  Son Ödeme (60-90)                     7184 non-null    float64
#  18  Son Ödeme (90-120)                    3820 non-null    float64
#  19  Son Ödeme (120-150)                   2302 non-null    float64
#  20  Son Ödeme (150-180)                   1551 non-null    float64
#  21  Son Ödeme (180+)                      4827 non-null    float64
# dtypes: float64(17), int64(1), object(4)
# memory usage: 154.0+ MB
# None
# ------------------------------
#
# İstatistiksel Özet:
#                                          count          mean           std  \
# Söz.hsp.(bağımsız)                    917632.0  5.010893e+09  2.883691e+09
# Tahakkuk Tutar                        917632.0  5.085794e+02  5.052666e+03
# Son Ödeme Tarihinden Önceki Tahsilat  623908.0  2.063125e+02  2.855302e+03
# Son Ödeme Tarihindeki Tahsilat        328193.0  5.472647e+02  3.898724e+03
# Son Ödeme (1)                          20902.0  6.430614e+02  5.454365e+03
# Son Ödeme (2)                          21664.0  5.537099e+02  5.123757e+03
# Son Ödeme (3)                          18893.0  4.144389e+02  2.650055e+03
# Son Ödeme (4)                          16995.0  5.363638e+02  6.242187e+03
# Son Ödeme (5)                           7323.0  5.160754e+02  3.451493e+03
# Son Ödeme (6-10)                       45708.0  5.586439e+02  6.666263e+03
# Son Ödeme (10-20)                      48281.0  5.835586e+02  7.178350e+03
# Son Ödeme (20-30)                      29005.0  8.010175e+02  7.154315e+03
# Son Ödeme (30-60)                      23030.0  9.186178e+02  7.105334e+03
# Son Ödeme (60-90)                       7184.0  1.257710e+03  2.007415e+04
# Son Ödeme (90-120)                      3820.0  6.716399e+02  5.979226e+03
# Son Ödeme (120-150)                     2302.0  3.221642e+02  3.220520e+03
# Son Ödeme (150-180)                     1551.0  3.933599e+02  5.264099e+03
# Son Ödeme (180+)                        4827.0  1.597766e+02  2.619162e+03
#
#                                             min           25%           50%  \
# Söz.hsp.(bağımsız)                    175832.00  2.513721e+09  5.009565e+09
# Tahakkuk Tutar                        -12793.28  1.101500e+02  2.020700e+02
# Son Ödeme Tarihinden Önceki Tahsilat  -12793.28  3.200000e-01  4.422000e+01
# Son Ödeme Tarihindeki Tahsilat             0.00  1.166000e+02  2.109900e+02
# Son Ödeme (1)                            -70.00  1.256100e+02  2.220000e+02
# Son Ödeme (2)                           -296.93  1.129225e+02  2.110000e+02
# Son Ödeme (3)                           -120.60  1.190000e+02  2.030000e+02
# Son Ödeme (4)                              0.00  1.169050e+02  2.080700e+02
# Son Ödeme (5)                           -752.00  1.150000e+02  2.185400e+02
# Son Ödeme (6-10)                        -100.66  1.219050e+02  2.135900e+02
# Son Ödeme (10-20)                       -962.00  1.150000e+02  2.100000e+02
# Son Ödeme (20-30)                          0.00  1.090000e+02  2.208800e+02
# Son Ödeme (30-60)                      -6837.00  7.700000e+01  1.729550e+02
# Son Ödeme (60-90)                       -701.00  4.285750e+01  1.070000e+02
# Son Ödeme (90-120)                      -770.00  3.033000e+01  7.600000e+01
# Son Ödeme (120-150)                     -349.00  2.412500e+01  5.537000e+01
# Son Ödeme (150-180)                        0.00  2.300000e+01  4.900000e+01
# Son Ödeme (180+)                      -15206.88  1.347000e+01  3.200000e+01
#
#                                                75%           max
# Söz.hsp.(bağımsız)                    7.509497e+09  9.999760e+09
# Tahakkuk Tutar                        3.215700e+02  1.173258e+06
# Son Ödeme Tarihinden Önceki Tahsilat  2.102200e+02  7.992989e+05
# Son Ödeme Tarihindeki Tahsilat        3.342700e+02  4.290566e+05
# Son Ödeme (1)                         3.499775e+02  3.932380e+05
# Son Ödeme (2)                         3.330000e+02  3.191200e+05
# Son Ödeme (3)                         3.200000e+02  1.523770e+05
# Son Ödeme (4)                         3.298650e+02  5.602390e+05
# Son Ödeme (5)                         3.449850e+02  1.580045e+05
# Son Ödeme (6-10)                      3.300000e+02  5.504209e+05
# Son Ödeme (10-20)                     3.340000e+02  5.508598e+05
# Son Ödeme (20-30)                     3.824700e+02  6.942759e+05
# Son Ödeme (30-60)                     3.209875e+02  2.217815e+05
# Son Ödeme (60-90)                     2.195575e+02  1.051591e+06
# Son Ödeme (90-120)                    1.640000e+02  1.502340e+05
# Son Ödeme (120-150)                   1.241300e+02  8.928568e+04
# Son Ödeme (150-180)                   1.065000e+02  1.694105e+05
# Son Ödeme (180+)                      7.600000e+01  1.410705e+05
# ------------------------------
#
# Veri seti:
# ------------------------------
#   Mali yıl/dönem      İl      İlçe  Söz.hsp.(bağımsız) Hesap Sınıfı  \
# 0       OCK 2023  AMASYA  GÖYNÜCEK          9374624783       Mesken
# 1       OCK 2023  AMASYA  GÖYNÜCEK           236184905       Mesken
# 2       OCK 2023  AMASYA  GÖYNÜCEK          9657731015       Mesken
# 3       OCK 2023  AMASYA  GÖYNÜCEK          9554442880       Mesken
# 4       OCK 2023  AMASYA  GÖYNÜCEK          6031642522       Mesken
#
#    Tahakkuk Tutar  Son Ödeme Tarihinden Önceki Tahsilat  \
# 0            5.03                                  0.03
# 1           26.46                                  0.06
# 2          121.53                                   NaN
# 3          117.49                                   NaN
# 4          170.30                                170.30
#
#    Son Ödeme Tarihindeki Tahsilat  Son Ödeme (1)  Son Ödeme (2)  ...  \
# 0                             NaN            NaN            NaN  ...
# 1                           26.40            NaN            NaN  ...
# 2                             NaN            NaN         121.53  ...
# 3                          117.49            NaN            NaN  ...
# 4                             NaN            NaN            NaN  ...
#
#    Son Ödeme (5)  Son Ödeme (6-10)  Son Ödeme (10-20)  Son Ödeme (20-30)  \
# 0            NaN               NaN                NaN                NaN
# 1            NaN               NaN                NaN                NaN
# 2            NaN               NaN                NaN                NaN
# 3            NaN               NaN                NaN                NaN
# 4            NaN               NaN                NaN                NaN
#
#    Son Ödeme (30-60)  Son Ödeme (60-90)  Son Ödeme (90-120)  \
# 0                NaN                NaN                 5.0
# 1                NaN                NaN                 NaN
# 2                NaN                NaN                 NaN
# 3                NaN                NaN                 NaN
# 4                NaN                NaN                 NaN
#
#    Son Ödeme (120-150)  Son Ödeme (150-180)  Son Ödeme (180+)
# 0                  NaN                  NaN               NaN
# 1                  NaN                  NaN               NaN
# 2                  NaN                  NaN               NaN
# 3                  NaN                  NaN               NaN
# 4                  NaN                  NaN               NaN
#
# [5 rows x 22 columns]
# ------------------------------
#
# ### Hamamözü (Tahakkuk) İncelemesi ###
# ------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124818 entries, 0 to 124817
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   il                 124818 non-null  object
#  1   ilce               124818 non-null  object
#  2   sozlesme_hesap_no  124818 non-null  int64
#  3   mali_yil_donem     124818 non-null  object
#  4   fatura_tarihi      124818 non-null  object
#  5   kayit_tarihi       124818 non-null  object
#  6   vade_tarihi        124818 non-null  object
#  7   hesap_sinifi       124818 non-null  object
#  8   Hesap Sınıfı       124818 non-null  object
#  9   kwh                124818 non-null  float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 9.5+ MB
# None
# ------------------------------
#
# İstatistiksel Özet:
#                       count          mean           std         min  \
# sozlesme_hesap_no  124818.0  5.044916e+09  2.874544e+09  2903944.00
# kwh                124818.0  7.087462e+01  3.892179e+02    -1242.99
#
#                             25%           50%           75%           max
# sozlesme_hesap_no  2.577471e+09  5.027442e+09  7.594090e+09  9.991894e+09
# kwh                1.549000e+01  4.056000e+01  7.043000e+01  2.594160e+04
# ------------------------------
#
# Veri seti:
# ------------------------------
#        il      ilce  sozlesme_hesap_no mali_yil_donem fatura_tarihi  \
# 0  AMASYA  HAMAMÖZÜ          917576806     2023-01-01    2023-01-12
# 1  AMASYA  HAMAMÖZÜ          917576806     2023-01-01    2023-02-09
# 2  AMASYA  HAMAMÖZÜ          917576806     2023-02-01    2023-02-09
# 3  AMASYA  HAMAMÖZÜ          917576806     2023-02-01    2023-03-10
# 4  AMASYA  HAMAMÖZÜ          917576806     2023-03-01    2023-03-10
#
#   kayit_tarihi vade_tarihi hesap_sinifi Hesap Sınıfı   kwh
# 0   2023-03-06  2023-01-23         M001       Mesken  1.79
# 1   2023-05-11  2023-02-20         M001       Mesken  2.60
# 2   2023-05-11  2023-02-20         M001       Mesken  1.23
# 3   2023-05-11  2023-03-20         M001       Mesken  2.56
# 4   2023-05-11  2023-03-20         M001       Mesken  1.35
# ------------------------------
#
# ### Gümüşhacıköy (Tahakkuk 1) İncelemesi ###
# ------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 765657 entries, 0 to 765656
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   il                 765657 non-null  object
#  1   ilce               765657 non-null  object
#  2   sozlesme_hesap_no  765657 non-null  int64
#  3   mali_yil_donem     765657 non-null  object
#  4   fatura_tarihi      765657 non-null  object
#  5   kayit_tarihi       765657 non-null  object
#  6   vade_tarihi        765657 non-null  object
#  7   hesap_sinifi       765657 non-null  object
#  8   Hesap Sınıfı       765657 non-null  object
#  9   kwh                765657 non-null  float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 58.4+ MB
# None
# ------------------------------
#
# İstatistiksel Özet:
#                       count          mean           std        min  \
# sozlesme_hesap_no  765657.0  5.019916e+09  2.881724e+09  256114.00
# kwh                765657.0  9.733663e+01  1.077758e+03  -25370.64
#
#                             25%           50%           75%           max
# sozlesme_hesap_no  2.519995e+09  5.030422e+09  7.517065e+09  9.998331e+09
# kwh                1.857000e+01  4.831000e+01  8.272000e+01  1.535757e+05
# ------------------------------
#
# Veri seti:
# ------------------------------
#        il          ilce  sozlesme_hesap_no mali_yil_donem fatura_tarihi  \
# 0  AMASYA  GÜMÜŞHACIKÖY         7444449517     2023-01-01    2023-01-11
# 1  AMASYA  GÜMÜŞHACIKÖY         7444449517     2023-01-01    2023-02-10
# 2  AMASYA  GÜMÜŞHACIKÖY         7444449517     2023-02-01    2023-02-10
# 3  AMASYA  GÜMÜŞHACIKÖY         7444449517     2023-02-01    2023-03-10
# 4  AMASYA  GÜMÜŞHACIKÖY         7444449517     2023-03-01    2023-03-10
#
#   kayit_tarihi vade_tarihi hesap_sinifi Hesap Sınıfı    kwh
# 0   2023-03-06  2023-01-23         M001       Mesken  21.85
# 1   2023-05-11  2023-02-20         M001       Mesken  44.50
# 2   2023-05-11  2023-02-20         M001       Mesken  22.25
# 3   2023-05-11  2023-03-20         M001       Mesken  45.71
# 4   2023-05-11  2023-03-20         M001       Mesken  25.40
# ------------------------------
#
# ### Göynücek (Tahakkuk 2) İncelemesi ###
# ------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295223 entries, 0 to 295222
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   il                 295223 non-null  object
#  1   ilce               295223 non-null  object
#  2   sozlesme_hesap_no  295223 non-null  int64
#  3   mali_yil_donem     295223 non-null  object
#  4   fatura_tarihi      295223 non-null  object
#  5   kayit_tarihi       295223 non-null  object
#  6   vade_tarihi        295223 non-null  object
#  7   hesap_sinifi       295223 non-null  object
#  8   Hesap Sınıfı       295223 non-null  object
#  9   kwh                295223 non-null  float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 22.5+ MB
# None
# ------------------------------
#
# İstatistiksel Özet:
#                       count          mean           std         min  \
# sozlesme_hesap_no  295223.0  4.950566e+09  2.887724e+09  1118550.00
# kwh                295223.0  8.966989e+01  7.422764e+02    -4208.64
#
#                             25%           50%           75%           max
# sozlesme_hesap_no  2.432854e+09  4.928206e+09  7.475616e+09  9.997185e+09
# kwh                1.786000e+01  4.509000e+01  7.714000e+01  1.056877e+05
# ------------------------------
#
# Veri seti:
# ------------------------------
#        il      ilce  sozlesme_hesap_no mali_yil_donem fatura_tarihi  \
# 0  AMASYA  GÖYNÜCEK         9374624783     2023-01-01    2023-01-14
# 1  AMASYA  GÖYNÜCEK         9374624783     2023-01-01    2025-03-12
# 2  AMASYA  GÖYNÜCEK         9374624783     2023-02-01    2025-03-12
# 3  AMASYA  GÖYNÜCEK         9374624783     2023-03-01    2025-03-12
# 4  AMASYA  GÖYNÜCEK         9374624783     2023-04-01    2025-03-12
#
#   kayit_tarihi vade_tarihi hesap_sinifi Hesap Sınıfı   kwh
# 0   2023-03-06  2023-01-24         M001       Mesken  0.10
# 1   2025-05-09  2025-03-24         M001       Mesken  0.12
# 2   2025-05-09  2025-03-24         M001       Mesken  0.20
# 3   2025-05-09  2025-03-24         M001       Mesken  0.00
# 4   2025-05-09  2025-03-24         M001       Mesken  0.08
# ------------------------------

# %%
print("\n### Benzersiz Müşteri Sayıları ###")
print(f"Hamamözü: {df_tahakkuk['sozlesme_hesap_no'].nunique()}")
print(f"Gümüşhacıköy: {df_tahakkuk_1['sozlesme_hesap_no'].nunique()}")
print(f"Göynücek: {df_tahakkuk_2['sozlesme_hesap_no'].nunique()}")
# Out:
# ### Benzersiz Müşteri Sayıları ###
# Hamamözü: 2981
# Gümüşhacıköy: 18190
# Göynücek: 7128

# %%
df_tuketim = pd.concat([df_tahakkuk, df_tahakkuk_1, df_tahakkuk_2], ignore_index=True)
print(f"Toplam Kayıt Sayısı: {df_tuketim.shape[0]}")
df_tuketim.ilce.value_counts()
# Out:
# Toplam Kayıt Sayısı: 1185698
# ilce
# GÜMÜŞHACIKÖY    765657
# GÖYNÜCEK        295223
# HAMAMÖZÜ        124818
# Name: count, dtype: int64

# %%
df_tuketim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1185698 entries, 0 to 1185697
# Data columns (total 10 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   il                 1185698 non-null  object
#  1   ilce               1185698 non-null  object
#  2   sozlesme_hesap_no  1185698 non-null  int64
#  3   mali_yil_donem     1185698 non-null  object
#  4   fatura_tarihi      1185698 non-null  object
#  5   kayit_tarihi       1185698 non-null  object
#  6   vade_tarihi        1185698 non-null  object
#  7   hesap_sinifi       1185698 non-null  object
#  8   Hesap Sınıfı       1185698 non-null  object
#  9   kwh                1185698 non-null  float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 90.5+ MB

# %%
kwh_null = df_tuketim['kwh'].isna().sum()
negatif_kwh = df_tuketim[df_tuketim['kwh'] < 0].shape[0]

print(f"Null Değer Sayısı: {kwh_null}")
print(f"Negatif Değer Sayısı: {negatif_kwh}")

# negatif değerli kwh
df_tuketim[df_tuketim['kwh'] < 0].head()
# Out:
# Null Değer Sayısı: 0
# Negatif Değer Sayısı: 151
#             il          ilce  sozlesme_hesap_no mali_yil_donem fatura_tarihi  \
# 23573   AMASYA      HAMAMÖZÜ         7904741733     2025-03-01    2025-04-14
# 23576   AMASYA      HAMAMÖZÜ         7904741733     2025-04-01    2025-04-14
# 28413   AMASYA      HAMAMÖZÜ          469034964     2023-10-01    2023-10-11
# 70626   AMASYA      HAMAMÖZÜ         7722066065     2023-10-01    2023-10-23
# 180501  AMASYA  GÜMÜŞHACIKÖY         2945215788     2024-02-01    2024-04-15
#
#        kayit_tarihi vade_tarihi hesap_sinifi Hesap Sınıfı      kwh
# 23573    2025-06-10  2025-04-22         M001       Mesken -1242.99
# 23576    2025-06-10  2025-04-22         M001       Mesken  -733.04
# 28413    2023-11-28  2023-10-23         M001       Mesken    -1.04
# 70626    2023-11-28  2023-11-02         M001       Mesken    -1.34
# 180501   2024-06-15  2024-03-25         M001       Mesken  -374.09

# %%
df_tuketim.groupby('Hesap Sınıfı')['kwh'].describe()[['count', 'mean', '50%', 'std']]
# Out:
#                                               count          mean        50%  \
# Hesap Sınıfı
# 1 SAYILI CETVELDE YER ALAN KAMU İDARESİ      8500.0    688.441598     23.860
# Aritma Tesisleri                               35.0  16594.174857  16186.910
# Balıkçılık ve Su Ürünleri Yetiştiriciliğ      124.0     85.358306     79.375
# Belediye                                     2097.0    600.581235     78.270
# Belediye Park Bahçe Aydınlatma                349.0     31.951003     18.390
# Bina Ort Kul (Asn,Hidr,Kapıcı Dai vb.)       3505.0     29.965663     15.760
# Büyükbaş-Küçükbaş Hayvancılık                1849.0    116.848021     24.110
# Cemevleri                                     916.0     10.713755      5.625
# Diyanet Kuran Kursu                            42.0    167.135000     22.115
# Doğal Afet Barınma                            116.0     73.615948     73.865
# Kar Amacı Güden Dernek,Vakıf,Müze             243.0     43.780576     13.520
# Karayolları Genel Müdürlüğü Aydınlatma         41.0  30203.431220  36810.900
# Köy İçme Suyu Temini ve Dağıtımı Tesisi      2460.0    676.935305    208.655
# Lisansız Üreticiler                           180.0  16155.254444    322.320
# Lisansız Üreticiler - Resmi Daire              36.0   1195.051389    770.625
# Mesken                                    1026609.0     55.590010     47.360
# Muhtarlık Hizmet Binaları                     383.0     34.289765      9.140
# Resmi Daire                                  1373.0    579.850961    150.830
# Resmi Daire Lojman                            614.0     93.101238     29.585
# Resmi Hayır Kurumları,Dernek,Vakıf,Müze       169.0     22.997456      8.820
# Resmi SAĞLIK KURULUŞLARI,RESMİ SPOR TES.      442.0   1154.739118    239.905
# Resmi Üniversite,Yük.Okul,Kurs,Yurt,Okul      476.0    883.888739    285.410
# Resmi İbadethane Isıtma/Soğutma/Lojman          7.0      9.097143      5.000
# Sanayi                                        187.0   7293.799626   1531.680
# Süt Toplama Merkezi                          1128.0    430.637801    187.405
# Tarımsal Faaliyetler (Kooperatif)            1632.0   3779.290533    282.720
# Tarımsal Faaliyetler (Şahıs)                17266.0    541.608449     16.150
# Ticari Faaliyet - Yazıhane                  91298.0    167.827953     41.600
# Ölçümsüz Aboneler (Resmi Daire)                46.0    395.160435     74.400
# İbadethane Aydınlatma                        3189.0     32.435252     13.940
# İbadethane Isıtma/Soğutma/Lojman            10173.0     81.283512     56.140
# İktisadi İşletmeleri Hariç Dernek ve Vkf      279.0    183.485878     89.760
# İç Tüketim                                    124.0    270.340000    228.680
# İçme-Kullanma Suyu (Belediye)                 417.0   5213.509281    400.020
# Şantiye ve Geçici Aboneler                   6706.0    136.952881     28.420
# Şantiye ve Geçici Aboneler (Belediye)          16.0      1.949375      0.095
# Şehit Aileleri ve Gaziler                    2671.0     87.035189     76.540
#
#                                                    std
# Hesap Sınıfı
# 1 SAYILI CETVELDE YER ALAN KAMU İDARESİ    3911.912974
# Aritma Tesisleri                          11656.705924
# Balıkçılık ve Su Ürünleri Yetiştiriciliğ     42.120066
# Belediye                                   3350.978976
# Belediye Park Bahçe Aydınlatma               38.472449
# Bina Ort Kul (Asn,Hidr,Kapıcı Dai vb.)       41.331395
# Büyükbaş-Küçükbaş Hayvancılık               408.549664
# Cemevleri                                    16.453958
# Diyanet Kuran Kursu                         526.354274
# Doğal Afet Barınma                           39.066907
# Kar Amacı Güden Dernek,Vakıf,Müze            74.313572
# Karayolları Genel Müdürlüğü Aydınlatma    16963.572539
# Köy İçme Suyu Temini ve Dağıtımı Tesisi    1212.334580
# Lisansız Üreticiler                       35926.424902
# Lisansız Üreticiler - Resmi Daire          1229.579483
# Mesken                                       73.902931
# Muhtarlık Hizmet Binaları                    60.020356
# Resmi Daire                                1693.273715
# Resmi Daire Lojman                          141.698975
# Resmi Hayır Kurumları,Dernek,Vakıf,Müze      42.496725
# Resmi SAĞLIK KURULUŞLARI,RESMİ SPOR TES.   3804.865088
# Resmi Üniversite,Yük.Okul,Kurs,Yurt,Okul   1435.311536
# Resmi İbadethane Isıtma/Soğutma/Lojman        9.346247
# Sanayi                                    13716.343807
# Süt Toplama Merkezi                        1131.991530
# Tarımsal Faaliyetler (Kooperatif)          9426.941321
# Tarımsal Faaliyetler (Şahıs)               3627.959619
# Ticari Faaliyet - Yazıhane                  781.762054
# Ölçümsüz Aboneler (Resmi Daire)             595.389083
# İbadethane Aydınlatma                       112.225490
# İbadethane Isıtma/Soğutma/Lojman            111.164648
# İktisadi İşletmeleri Hariç Dernek ve Vkf    205.340833
# İç Tüketim                                  148.809345
# İçme-Kullanma Suyu (Belediye)              8948.065839
# Şantiye ve Geçici Aboneler                  798.495578
# Şantiye ve Geçici Aboneler (Belediye)         3.138306
# Şehit Aileleri ve Gaziler                    56.599681

# %%
# kwh sütunu için outlier tespiti

Q1 = df_tuketim['kwh'].quantile(0.25)
Q3 = df_tuketim['kwh'].quantile(0.75)
IQR = Q3 - Q1

alt_sinir = Q1 - 1.5 * IQR
ust_sinir = Q3 + 1.5 * IQR

print(f"Alt Sınır: {alt_sinir:.2f} kWh")
print(f"Üst Sınır: {ust_sinir:.2f} kWh")

outliers = df_tuketim[(df_tuketim['kwh'] < alt_sinir) | (df_tuketim['kwh'] > ust_sinir)]

print(f"\nTotal outlier sayısı: {len(outliers)}")
print(f"Toplam Veriye Oranı: %{len(outliers) / len(df_tuketim) * 100:.2f}")
# Out:
# Alt Sınır: -74.97 kWh
# Üst Sınır: 172.98 kWh
#
# Total outlier sayısı: 48554
# Toplam Veriye Oranı: %4.09
